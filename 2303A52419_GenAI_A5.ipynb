# %% [markdown]
# <a href="https://colab.research.google.com/github/Anjani2707/GEN_AI_2303A52419/blob/main/2303A52419_GenAI_A5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
data = {'x1': [0.1,0.2,0.3,0.6,0.7,0.8],
        'x2': [0.2,0.3,0.4,0.7,0.8,0.9],
        'y': [0.3432,0.3490,0.3548,0.3720,0.3776,0.3832,]}

train_data = pd.DataFrame(data)
train_data
# Out:
#     x1   x2       y
# 0  0.1  0.2  0.3432
# 1  0.2  0.3  0.3490
# 2  0.3  0.4  0.3548
# 3  0.6  0.7  0.3720
# 4  0.7  0.8  0.3776
# 5  0.8  0.9  0.3832

# %%
test_data = {
    'x1':[0.4,0.5],
    'x2':[0.5,0.6],
    'y':[0.3606,0.3663]
}
test_data = pd.DataFrame(test_data)
test_data
# Out:
#     x1   x2       y
# 0  0.4  0.5  0.3606
# 1  0.5  0.6  0.3663

# %%
x=train_data.drop('y',axis=1)
y=train_data['y']

# %%
weights = np.random.rand(2)
print(weights)
bias = np.random.rand(1)
print(bias)
eta = 0.01
epochs = 1000
# Out:
# [0.21233911 0.18182497]
# [0.18340451]

# %%
def linear_activation(x):
    return x

# %%
def predict(X, weights, bias):
    return np.dot(X, weights) + bias

# %%
def mean_squared_error(y_true, y_pred):
    return np.mean((y_true - y_pred) ** 2)

# %%
for epoch in range(epochs):
    # Forward pass
    y_pred = predict(x, weights, bias)

    # Compute gradients
    error = y_pred - y
    dw = (2 / len(y)) * np.dot(x.T, error)
    db = (2 / len(y)) * np.sum(error)

    # Update weights and bias
    weights -= eta * dw
    bias -= eta * db

    # Print loss every 100 epochs
    if (epoch + 1) % 100 == 0:
        loss = mean_squared_error(y, y_pred)
        print(f"Epoch {epoch + 1}/{epochs}, Loss: {loss:.6f}")
# Out:
# Epoch 100/1000, Loss: 0.004984
# Epoch 200/1000, Loss: 0.003482
# Epoch 300/1000, Loss: 0.002434
# Epoch 400/1000, Loss: 0.001701
# Epoch 500/1000, Loss: 0.001189
# Epoch 600/1000, Loss: 0.000831
# Epoch 700/1000, Loss: 0.000581
# Epoch 800/1000, Loss: 0.000406
# Epoch 900/1000, Loss: 0.000284
# Epoch 1000/1000, Loss: 0.000198

# %%
y_train_pred = predict(x, weights, bias)
train_mse = mean_squared_error(y, y_train_pred)
print(f"\nTraining MSE: {train_mse:.6f}")
# Out:
# Training MSE: 0.000198

# %%
x_test=test_data.drop('y',axis=1)
y_test=test_data['y']

# %%
y_test_pred = predict(x_test, weights, bias)
test_mse = mean_squared_error(y_test, y_test_pred)
print(f"Testing MSE: {test_mse:.6f}")
# Out:
# Testing MSE: 0.000014

# %%
user_input = input("\nEnter values for x1, x2, x3 (comma-separated): ")
user_data = np.array([float(x) for x in user_input.split(",")])
user_prediction = predict(user_data.reshape(1, -1), weights, bias)
print(f"Predicted output: {user_prediction[0]:.4f}")
# Out:
# Enter values for x1, x2, x3 (comma-separated): 2 , 3
# Predicted output: 0.5720
